# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ### Data loading and data preprocessing

# %%
df = pd.read_csv('sonar data.csv', header = None)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
X = df.drop(columns = 60, axis=1)
y = df[60]

# %% [markdown]
# ### Spliting data into train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, stratify = y, random_state = 2023)

# %% [markdown]
# ## Using sklearn lib

# %% [markdown]
# ### Model training -- logistics regression

# %%
model = LogisticRegression().fit(X_train, y_train)

# %% [markdown]
# ### Model evaluation

# %%
# Model evaluation on train data
train_pred = model.predict(X_train)
print('Accuracy score on train data: ', accuracy_score(train_pred, y_train))
# Out:
# Accuracy score on train data:  0.8235294117647058

# %%
# Model evaluation on test data
test_pred = model.predict(X_test)
print('Accuracy score on test data: ', accuracy_score(test_pred, y_test))
# Out:
# Accuracy score on test data:  0.8571428571428571

# %%
def prediction(input):
    pred = model.predict([list(input)])
    return 'Rock' if pred == "R" else 'Mine'

input = (0.0453,0.0523,0.0843,0.0689,0.1183,0.2583,0.2156,0.3481,0.3337,0.2872,0.4918,0.6552,0.6919,0.7797,0.7464,0.9444,1.0000,0.8874,0.8024,0.7818,0.5212,0.4052,0.3957,0.3914,0.3250,0.3200,0.3271,0.2767,0.4423,0.2028,0.3788,0.2947,0.1984,0.2341,0.1306,0.4182,0.3835,0.1057,0.1840,0.1970,0.1674,0.0583,0.1401,0.1628,0.0621,0.0203,0.0530,0.0742,0.0409,0.0061,0.0125,0.0084,0.0089,0.0048,0.0094,0.0191,0.0140,0.0049,0.0052,0.0044)
print('The object is', prediction(input))
# Out:
# The object is Mine

# %% [markdown]
# ## Using tensorflow

# %%
def custom_label(x):
    if x=='R': return 1
    else: return 0
y_train = y_train.apply(lambda x : custom_label(x))
y_test = y_test.apply(lambda x : custom_label(x))

# %%
X_train = tf.convert_to_tensor(X_train)
y_train = tf.convert_to_tensor(y_train)

X_test = tf.convert_to_tensor(X_test)
y_test = tf.convert_to_tensor(y_test)

# %%
model = tf.keras.Sequential([
    layers.Dense(units = 32, activation = 'relu', input_shape = [60]),
    layers.Dense(units=1,activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 6/6 [==============================] - 1s 3ms/step - loss: 0.7327 - accuracy: 0.5348
# Epoch 2/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7138 - accuracy: 0.5401
# Epoch 3/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6993 - accuracy: 0.5241
# Epoch 4/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6876 - accuracy: 0.5508
# Epoch 5/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6781 - accuracy: 0.5561
# Epoch 6/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6678 - accuracy: 0.5615
# Epoch 7/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6593 - accuracy: 0.5936
# Epoch 8/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6507 - accuracy: 0.6203
# Epoch 9/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6429 - accuracy: 0.6364
# Epoch 10/50
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 1/1 [==============================] - 0s 98ms/step - loss: 0.4714 - accuracy: 0.8095
# Accuracy: 80.95
